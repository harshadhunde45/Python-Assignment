# %%
t = ()
type(t)
# Out:
# tuple

# %%
#tuples are ordered collection of elements, heterogenous
#immutables
t = ("pwskills", 7+3j, 1, 1.2)

# %%
t
# Out:
# ('pwskills', (7+3j), 1, 1.2)

# %%
t[0]
# Out:
# 'pwskills'

# %%
t[0] = "some value" #tuples are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 t[0] = "some value"
#
# TypeError: 'tuple' object does not support item assignment

# %%
emp_id = (1, 2, 3, 4, 1, 1, 1)
emp_id[1]
# Out:
# 2

# %%
emp_id.count(1)
# Out:
# 4

# %%
emp_id.index(2)
# Out:
# 1

# %%
len(emp_id)
# Out:
# 7

# %%
#tuples>>(), list []

# %%
emp_id * 2
# Out:
# (1, 2, 3, 4, 1, 1, 1, 1, 2, 3, 4, 1, 1, 1)

# %%
emp_id[:]
# Out:
# (1, 2, 3, 4, 1, 1, 1)

# %%
emp_id[-1]
# Out:
# 1

# %%
emp_id[::-1]
# Out:
# (1, 1, 1, 4, 3, 2, 1)

# %%
for i in emp_id:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 1
# 1
# 1

# %%
t1 = (100, 2, 1, 3, 1000)
max(t1)
# Out:
# 1000

# %%
min(t1)
# Out:
# 1

# %%
t2 = (1, 2, 3)

# %%
t2
# Out:
# (1, 2, 3)

# %%
t1
# Out:
# (100, 2, 1, 3, 1000)

# %%
(t1, t2)
# Out:
# ((100, 2, 1, 3, 1000), (1, 2, 3))

# %%
t1+t2
# Out:
# (100, 2, 1, 3, 1000, 1, 2, 3)

# %%
len(t2)
# Out:
# 3

# %%
100 in t1
# Out:
# True

# %%
t1.index(2)
# Out:
# 1

# %%
t3 = t1+t2

# %%
t3.index(1)
# Out:
# 2

# %%
t3
# Out:
# (100, 2, 1, 3, 1000, 1, 2, 3)

# %%
list(t3)
# Out:
# [100, 2, 1, 3, 1000, 1, 2, 3]

# %%
#set >> sets are collection of unique and unordered elements
#doesnt allow duplicate elements>> doent maintain any order and it will will not be indexed

# %%
s = {}
type(s)
# Out:
# dict

# %%
s = {1, 2, 1, 2, 1, 2, 1}
s
# Out:
# {1, 2}

# %%
s = {1, 2, 1, 2, 1, "Ajay", "Ajay", "ajay"}

# %%
s
# Out:
# {1, 2, 'Ajay', 'ajay'}

# %%
#set
s[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 #set
# ----> 2 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s = {1, 2, 'Ajay', 'ajay', [1, 2, 3]} #set can not have mutable data structure inside it
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 s = {1, 2, 'Ajay', 'ajay', [1, 2, 3]}
#
# TypeError: unhashable type: 'list'

# %%
s = {1, 2, 'Ajay', 'ajay', (1, 2, 3)}

# %%
s
# Out:
# {(1, 2, 3), 1, 2, 'Ajay', 'ajay'}

# %%
s = {1, 2, 'Ajay', 'ajay', {1, 2, 3}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 s = {1, 2, 'Ajay', 'ajay', {1, 2, 3}}
#
# TypeError: unhashable type: 'set'

# %%
s[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 s[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
len(s)
# Out:
# 5

# %%
for i in s:
    print(i)
# Out:
# 1
# 2
# ajay
# Ajay
# (1, 2, 3)

# %%
s.add(100)

# %%
s
# Out:
# {(1, 2, 3), 1, 100, 2, 'Ajay', 'ajay'}

# %%
s.pop()
# Out:
# 1

# %%
s
# Out:
# {(1, 2, 3), 100, 2, 'Ajay', 'ajay'}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {(1, 2, 3), 100, 'Ajay', 'ajay'}

# %%
s.remove(100)

# %%
s
# Out:
# {(1, 2, 3), 'Ajay', 'ajay'}

# %%
s.update(["Bijay"])

# %%
s
# Out:
# {(1, 2, 3), 'Ajay', 'B', 'Bijay', 'a', 'ajay', 'i', 'j', 'y'}

# %%
s.update([1, 2, 3])

# %%
s
# Out:
# {(1, 2, 3), 1, 2, 3, 'Ajay', 'B', 'Bijay', 'a', 'ajay', 'i', 'j', 'y'}

# %%
s
# Out:
# {(1, 2, 3), 1, 2, 3, 'Ajay', 'B', 'Bijay', 'a', 'ajay', 'i', 'j', 'y'}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
del s

# %%
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 s
#
# NameError: name 's' is not defined

# %%
#set operations, dictionary and functions
